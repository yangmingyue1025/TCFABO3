# %%
import re

# 测试文件名
test_filename = "InRhO3(mp-1203220).csv"

# 匹配化学式和mp-id
match = re.search(r'([a-zA-Z0-9]+)\(mp-\d+\)', test_filename)
if match:
    formula = match.group(1)
    mp_id = re.search(r'mp-(\d+)', test_filename).group(1)
    print(f"Formula: {formula}, mp-id: {mp_id}")
else:
    print(f"Invalid file name format: {test_filename}")
# Out:
# Formula: InRhO3, mp-id: 1203220

# %%
import os
import pandas as pd


csv_folder_path = '/coordination number change cubic/'
external_csv_path = 'Ionic dielectric polarizabilityy.csv'
output_folder = '/Ionic radium/'


if not os.path.exists(output_folder):
    os.makedirs(output_folder)


external_df = pd.read_csv(external_csv_path)


for csv_file in os.listdir(csv_folder_path):
    if csv_file.endswith('.csv'):
        file_path = os.path.join(csv_folder_path, csv_file)
        df = pd.read_csv(file_path)

        all_matched = True

        df['IR'] = None


        for index, row in df.iterrows():
            element = row['ion']
            v = row['V']
            cn = row['cn']


            match = external_df[(external_df['Element'] == element) & (external_df['V'] == v) & (external_df['CN'] == cn)]
            if not match.empty:
                df.at[index, 'IR'] = match['IR'].values[0]
            else:
                all_matched = False
                break


        if all_matched:
            output_file = os.path.join(output_folder, csv_file)
            df.to_csv(output_file, index=False)
            print(f"Saved new CSV file for {csv_file} to {output_file}")

print("Processing complete.")
# Out:
# Saved new CSV file for Ba3ZrIr2O9(mp-1214509).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3ZrIr2O9(mp-1214509).csv
# Saved new CSV file for Ba2SmWO6(mp-1517191).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmWO6(mp-1517191).csv
# Saved new CSV file for InRhO3(mp-1203220).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/InRhO3(mp-1203220).csv
# Saved new CSV file for Mg2SbWO6(mp-1047279).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2SbWO6(mp-1047279).csv
# Saved new CSV file for TbVO3(mp-1187389).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbVO3(mp-1187389).csv
# Saved new CSV file for Ba2ScTaO6(mp-1205823).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2ScTaO6(mp-1205823).csv
# Saved new CSV file for Sr2UInO6(mp-1206007).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2UInO6(mp-1206007).csv
# Saved new CSV file for MnZnO3(mp-772528).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnZnO3(mp-772528).csv
# Saved new CSV file for BaIrO3(mp-5660).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaIrO3(mp-5660).csv
# Saved new CSV file for Ba2GdNbO6(mp-19996).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2GdNbO6(mp-19996).csv
# Saved new CSV file for Ba2GdUO6(mp-1205845).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2GdUO6(mp-1205845).csv
# Saved new CSV file for EuAgO3(mp-1077622).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuAgO3(mp-1077622).csv
# Saved new CSV file for La2ZnCoO6(mp-1272890).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2ZnCoO6(mp-1272890).csv
# Saved new CSV file for Ba3Ta2MnO9(mp-1214505).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Ta2MnO9(mp-1214505).csv
# Saved new CSV file for SrRuO3(mp-4525).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrRuO3(mp-4525).csv
# Saved new CSV file for SmCrO3(mp-19257).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmCrO3(mp-19257).csv
# Saved new CSV file for Tb2CoPtO6(mp-1208543).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Tb2CoPtO6(mp-1208543).csv
# Saved new CSV file for BaPrO3(mp-4783).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaPrO3(mp-4783).csv
# Saved new CSV file for LiVO3(mp-754098).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiVO3(mp-754098).csv
# Saved new CSV file for K3NaRe2O9(mp-541393).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/K3NaRe2O9(mp-541393).csv
# Saved new CSV file for CuAsO3(mp-776320).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CuAsO3(mp-776320).csv
# Saved new CSV file for CeSbO3(mp-38685).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeSbO3(mp-38685).csv
# Saved new CSV file for Ca2MnNiO6(mp-1326305).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2MnNiO6(mp-1326305).csv
# Saved new CSV file for EuScO3(mp-22487).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuScO3(mp-22487).csv
# Saved new CSV file for LiIO3(mp-1180548).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiIO3(mp-1180548).csv
# Saved new CSV file for La2TiCrO6(mp-1225793).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2TiCrO6(mp-1225793).csv
# Saved new CSV file for LiTaO3(mp-1105280).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiTaO3(mp-1105280).csv
# Saved new CSV file for Ba2TbWO6(mp-1214561).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TbWO6(mp-1214561).csv
# Saved new CSV file for Mg2BiPO6(mp-555257).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2BiPO6(mp-555257).csv
# Saved new CSV file for Ba2SrSeO6(mp-1523293).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SrSeO6(mp-1523293).csv
# Saved new CSV file for Sr2ZrSnO6(mp-1522474).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ZrSnO6(mp-1522474).csv
# Saved new CSV file for Sr2HfZrO6(mp-1519753).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2HfZrO6(mp-1519753).csv
# Saved new CSV file for Ba3NiSb2O9(mp-17269).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3NiSb2O9(mp-17269).csv
# Saved new CSV file for AlFeO3(mp-1398131).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlFeO3(mp-1398131).csv
# Saved new CSV file for Ca2NbFeO6(mp-1214121).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2NbFeO6(mp-1214121).csv
# Saved new CSV file for HoGaO3(mp-769045).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoGaO3(mp-769045).csv
# Saved new CSV file for Ca2TaCuO6(mp-1346599).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TaCuO6(mp-1346599).csv
# Saved new CSV file for Sr2LuTaO6(mp-1205553).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2LuTaO6(mp-1205553).csv
# Saved new CSV file for Sm2TiCuO6(mp-1219251).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sm2TiCuO6(mp-1219251).csv
# Saved new CSV file for EuCuO3(mp-1338333).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuCuO3(mp-1338333).csv
# Saved new CSV file for Ca2CoWO6(mp-1045281).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2CoWO6(mp-1045281).csv
# Saved new CSV file for Eu2HoTaO6(mp-1181527).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2HoTaO6(mp-1181527).csv
# Saved new CSV file for Zn2BiSbO6(mp-1342422).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2BiSbO6(mp-1342422).csv
# Saved new CSV file for HoInO3(mp-776984).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoInO3(mp-776984).csv
# Saved new CSV file for RbPO3(mp-616587).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/RbPO3(mp-616587).csv
# Saved new CSV file for Zn2CrSbO6(mp-1347006).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2CrSbO6(mp-1347006).csv
# Saved new CSV file for Ba2MnNbO6(mp-1272179).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2MnNbO6(mp-1272179).csv
# Saved new CSV file for Li2VPO6(mp-616566).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Li2VPO6(mp-616566).csv
# Saved new CSV file for Sr2ScBiO6(mp-1208736).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ScBiO6(mp-1208736).csv
# Saved new CSV file for SrSnO3(mp-546973).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrSnO3(mp-546973).csv
# Saved new CSV file for Nd2VFeO6(mp-1220528).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Nd2VFeO6(mp-1220528).csv
# Saved new CSV file for Sr2ScTaO6(mp-1208776).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ScTaO6(mp-1208776).csv
# Saved new CSV file for Ca2TeWO6(mp-1047738).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TeWO6(mp-1047738).csv
# Saved new CSV file for VBO3(mp-18946).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VBO3(mp-18946).csv
# Saved new CSV file for SrSnO3(mp-12866).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrSnO3(mp-12866).csv
# Saved new CSV file for Li3P2WO9(mp-757576).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Li3P2WO9(mp-757576).csv
# Saved new CSV file for Na2BiWO6(mp-1522988).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Na2BiWO6(mp-1522988).csv
# Saved new CSV file for VZnO3(mp-1378086).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VZnO3(mp-1378086).csv
# Saved new CSV file for Ba2LaSbO6(mp-1523089).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2LaSbO6(mp-1523089).csv
# Saved new CSV file for AgGeO3(mp-759939).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AgGeO3(mp-759939).csv
# Saved new CSV file for BaSeO3(mp-6989).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaSeO3(mp-6989).csv
# Saved new CSV file for LiVO3(mp-763200).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiVO3(mp-763200).csv
# Saved new CSV file for Ba2ScUO6(mp-1206763).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2ScUO6(mp-1206763).csv
# Saved new CSV file for Ba2TbCeO6(mp-1520056).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TbCeO6(mp-1520056).csv
# Saved new CSV file for Zn2AgWO6(mp-1378705).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2AgWO6(mp-1378705).csv
# Saved new CSV file for Sr2ZrTiO6(mp-1518526).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ZrTiO6(mp-1518526).csv
# Saved new CSV file for Ca2TiIrO6(mp-1340170).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TiIrO6(mp-1340170).csv
# Saved new CSV file for MnSO3(mp-560522).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnSO3(mp-560522).csv
# Saved new CSV file for Sr2TaCrO6(mp-31624).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TaCrO6(mp-31624).csv
# Saved new CSV file for FeBO3(mp-19097).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/FeBO3(mp-19097).csv
# Saved new CSV file for CaSiO3(mp-4356).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaSiO3(mp-4356).csv
# Saved new CSV file for Ba2InBiO6(mp-1228393).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2InBiO6(mp-1228393).csv
# Saved new CSV file for LaAlO3(mp-2920).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaAlO3(mp-2920).csv
# Saved new CSV file for HoBO3(mp-752713).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoBO3(mp-752713).csv
# Saved new CSV file for Ba2YIrO6(mp-15888).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2YIrO6(mp-15888).csv
# Saved new CSV file for Y2TiCuO6(mp-1216142).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Y2TiCuO6(mp-1216142).csv
# Saved new CSV file for AlFeO3(mp-1264966).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlFeO3(mp-1264966).csv
# Saved new CSV file for La2MnVO6(mp-560369).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MnVO6(mp-560369).csv
# Saved new CSV file for TiNiO3(mp-850194).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiNiO3(mp-850194).csv
# Saved new CSV file for Sr2CeSbO6(mp-1518851).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CeSbO6(mp-1518851).csv
# Saved new CSV file for LaCoO3(mp-1504268).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaCoO3(mp-1504268).csv
# Saved new CSV file for TlCoO3(mp-770614).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TlCoO3(mp-770614).csv
# Saved new CSV file for Sr2CeNiO6(mp-1517357).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CeNiO6(mp-1517357).csv
# Saved new CSV file for HfSnO3(mp-776083).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HfSnO3(mp-776083).csv
# Saved new CSV file for CaRuO3(mp-20947).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaRuO3(mp-20947).csv
# Saved new CSV file for SrCoO3(mp-550781).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrCoO3(mp-550781).csv
# Saved new CSV file for CeScO3(mp-777413).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeScO3(mp-777413).csv
# Saved new CSV file for MoHO3(mp-1221516).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MoHO3(mp-1221516).csv
# Saved new CSV file for NaNbO3(mp-4514).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaNbO3(mp-4514).csv
# Saved new CSV file for TiCdO3(mp-1179551).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiCdO3(mp-1179551).csv
# Saved new CSV file for CaGeO3(mp-1016884).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaGeO3(mp-1016884).csv
# Saved new CSV file for YCoO3(mp-1387356).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YCoO3(mp-1387356).csv
# Saved new CSV file for BaPbO3(mp-22230).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaPbO3(mp-22230).csv
# Saved new CSV file for CdTcO3(mp-1189706).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdTcO3(mp-1189706).csv
# Saved new CSV file for NdAlO3(mp-5899).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdAlO3(mp-5899).csv
# Saved new CSV file for Sr2VMoO6(mp-1294847).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2VMoO6(mp-1294847).csv
# Saved new CSV file for TbTiO3(mp-768409).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbTiO3(mp-768409).csv
# Saved new CSV file for LaCuO3(mp-3474).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaCuO3(mp-3474).csv
# Saved new CSV file for CaMnO3(mp-1017467).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaMnO3(mp-1017467).csv
# Saved new CSV file for CdSnO3(mp-1016881).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdSnO3(mp-1016881).csv
# Saved new CSV file for SiHgO3(mp-1016874).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SiHgO3(mp-1016874).csv
# Saved new CSV file for Ca2NiWO6(mp-556384).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2NiWO6(mp-556384).csv
# Saved new CSV file for CsPuO3(mp-2647156).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsPuO3(mp-2647156).csv
# Saved new CSV file for LaGaO3(mp-5837).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaGaO3(mp-5837).csv
# Saved new CSV file for Sr2FeBiO6(mp-1205525).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2FeBiO6(mp-1205525).csv
# Saved new CSV file for SrMnO3(mp-19001).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrMnO3(mp-19001).csv
# Saved new CSV file for Ba2VBiO6(mp-1522771).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2VBiO6(mp-1522771).csv
# Saved new CSV file for Ba2SmCrO6(mp-1523051).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmCrO6(mp-1523051).csv
# Saved new CSV file for SnHgO3(mp-13554).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SnHgO3(mp-13554).csv
# Saved new CSV file for Sr2NdTaO6(mp-1208759).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NdTaO6(mp-1208759).csv
# Saved new CSV file for TbMgO3(mp-1187347).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbMgO3(mp-1187347).csv
# Saved new CSV file for Sr2TbReO6(mp-13937).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TbReO6(mp-13937).csv
# Saved new CSV file for TlSbO3(mp-30058).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TlSbO3(mp-30058).csv
# Saved new CSV file for Ba3Fe2WO9(mp-1228376).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Fe2WO9(mp-1228376).csv
# Saved new CSV file for Sr2CeCoO6(mp-1516664).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CeCoO6(mp-1516664).csv
# Saved new CSV file for ZnSnO3(mp-1337169).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ZnSnO3(mp-1337169).csv
# Saved new CSV file for Gd2NiPtO6(mp-1212708).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Gd2NiPtO6(mp-1212708).csv
# Saved new CSV file for YCrO3(mp-18770).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YCrO3(mp-18770).csv
# Saved new CSV file for MnCO3(mp-1078473).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnCO3(mp-1078473).csv
# Saved new CSV file for PrNiO3(mp-19170).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/PrNiO3(mp-19170).csv
# Saved new CSV file for Ba2EuRuO6(mp-1205665).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2EuRuO6(mp-1205665).csv
# Saved new CSV file for LiSbO3(mp-752636).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiSbO3(mp-752636).csv
# Saved new CSV file for Sr2VMoO6(mp-1278734).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2VMoO6(mp-1278734).csv
# Saved new CSV file for CsAsO3(mp-1183911).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsAsO3(mp-1183911).csv
# Saved new CSV file for Ba2VFeO6(mp-1096783).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2VFeO6(mp-1096783).csv
# Saved new CSV file for SmInO3(mp-752437).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmInO3(mp-752437).csv
# Saved new CSV file for LaMnO3(mp-19025).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaMnO3(mp-19025).csv
# Saved new CSV file for Ba2FeWO6(mp-1272506).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2FeWO6(mp-1272506).csv
# Saved new CSV file for CrInO3(mp-756147).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CrInO3(mp-756147).csv
# Saved new CSV file for Sr2NdNbO6(mp-1207215).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NdNbO6(mp-1207215).csv
# Saved new CSV file for La3Mg2TaO9(mp-1223326).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La3Mg2TaO9(mp-1223326).csv
# Saved new CSV file for MnCdO3(mp-1016854).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnCdO3(mp-1016854).csv
# Saved new CSV file for Ba2MnNbO6(mp-1278519).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2MnNbO6(mp-1278519).csv
# Saved new CSV file for Ba2FeMoO6(mp-18995).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2FeMoO6(mp-18995).csv
# Saved new CSV file for CoAgO3(mp-752700).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CoAgO3(mp-752700).csv
# Saved new CSV file for Sm2VFeO6(mp-1219215).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sm2VFeO6(mp-1219215).csv
# Saved new CSV file for Mg2MnSbO6(mp-1275484).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2MnSbO6(mp-1275484).csv
# Saved new CSV file for Sr2GdRuO6(mp-1079192).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2GdRuO6(mp-1079192).csv
# Saved new CSV file for La2CoNiO6(mp-1275360).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2CoNiO6(mp-1275360).csv
# Saved new CSV file for MgVO3(mp-1370061).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgVO3(mp-1370061).csv
# Saved new CSV file for AlNiO3(mp-1376903).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlNiO3(mp-1376903).csv
# Saved new CSV file for Zn2NiSbO6(mp-1339909).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2NiSbO6(mp-1339909).csv
# Saved new CSV file for SmVO3(mp-1188225).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmVO3(mp-1188225).csv
# Saved new CSV file for Sr3Co2WO9(mp-1218612).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr3Co2WO9(mp-1218612).csv
# Saved new CSV file for Ca2MnWO6(mp-19108).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2MnWO6(mp-19108).csv
# Saved new CSV file for Ba2LaIrO6(mp-1080123).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2LaIrO6(mp-1080123).csv
# Saved new CSV file for Ba2PrBiO6(mp-1214573).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrBiO6(mp-1214573).csv
# Saved new CSV file for YBO3(mp-1100876).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YBO3(mp-1100876).csv
# Saved new CSV file for LaNiO3(mp-19339).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaNiO3(mp-19339).csv
# Saved new CSV file for Sr2ZrCoO6(mp-1079027).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ZrCoO6(mp-1079027).csv
# Saved new CSV file for TiFeO3(mp-20073).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiFeO3(mp-20073).csv
# Saved new CSV file for VHO3(mp-627119).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VHO3(mp-627119).csv
# Saved new CSV file for SrTcO3(mp-12631).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrTcO3(mp-12631).csv
# Saved new CSV file for Sr2MnWO6(mp-1519277).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2MnWO6(mp-1519277).csv
# Saved new CSV file for LiNbO3(mp-760701).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiNbO3(mp-760701).csv
# Saved new CSV file for BaPaO3(mp-8557).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaPaO3(mp-8557).csv
# Saved new CSV file for NaAsO3(mp-976133).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaAsO3(mp-976133).csv
# Saved new CSV file for NaNbO3(mp-1199037).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaNbO3(mp-1199037).csv
# Saved new CSV file for CdSO3(mp-556680).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdSO3(mp-556680).csv
# Saved new CSV file for Eu2TmTaO6(mp-1205480).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2TmTaO6(mp-1205480).csv
# Saved new CSV file for Ba2CeBiO6(mp-1519226).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2CeBiO6(mp-1519226).csv
# Saved new CSV file for Ba2NaOsO6(mp-22442).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NaOsO6(mp-22442).csv
# Saved new CSV file for Eu2HfNbO6(mp-1518357).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2HfNbO6(mp-1518357).csv
# Saved new CSV file for Mn2BiPO6(mp-554449).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mn2BiPO6(mp-554449).csv
# Saved new CSV file for CaNbO3(mp-4957).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaNbO3(mp-4957).csv
# Saved new CSV file for Ba2UCuO6(mp-1205359).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2UCuO6(mp-1205359).csv
# Saved new CSV file for TbMnO3(mp-22055).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbMnO3(mp-22055).csv
# Saved new CSV file for Mg2VBiO6(mp-23111).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2VBiO6(mp-23111).csv
# Saved new CSV file for Sr2CoRuO6(mp-1218846).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CoRuO6(mp-1218846).csv
# Saved new CSV file for GdBO3(mp-29762).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GdBO3(mp-29762).csv
# Saved new CSV file for Ba2SrUO6(mp-1079113).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SrUO6(mp-1079113).csv
# Saved new CSV file for MgCrO3(mp-1346485).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgCrO3(mp-1346485).csv
# Saved new CSV file for Ba3CaBi2O9(mp-1228277).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3CaBi2O9(mp-1228277).csv
# Saved new CSV file for SmErO3(mp-754203).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmErO3(mp-754203).csv
# Saved new CSV file for AlCoO3(mp-756947).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlCoO3(mp-756947).csv
# Saved new CSV file for Sr2CaOsO6(mp-1206283).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CaOsO6(mp-1206283).csv
# Saved new CSV file for Ca2MnSbO6(mp-1227483).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2MnSbO6(mp-1227483).csv
# Saved new CSV file for Sr2ErReO6(mp-13939).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ErReO6(mp-13939).csv
# Saved new CSV file for SmAlO3(mp-7405).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmAlO3(mp-7405).csv
# Saved new CSV file for La2VFeO6(mp-1651775).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2VFeO6(mp-1651775).csv
# Saved new CSV file for YErO3(mp-755109).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YErO3(mp-755109).csv
# Saved new CSV file for VCrO3(mp-757023).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VCrO3(mp-757023).csv
# Saved new CSV file for Ba2TbZrO6(mp-1520812).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TbZrO6(mp-1520812).csv
# Saved new CSV file for Ti2MnNiO6(mp-1217119).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ti2MnNiO6(mp-1217119).csv
# Saved new CSV file for Ba2PuZnO6(mp-1207069).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PuZnO6(mp-1207069).csv
# Saved new CSV file for SrHfO3(mp-13109).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrHfO3(mp-13109).csv
# Saved new CSV file for CaSiO3(mp-3387).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaSiO3(mp-3387).csv
# Saved new CSV file for LaMnO3(mp-1272373).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaMnO3(mp-1272373).csv
# Saved new CSV file for KBiO3(mp-29799).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KBiO3(mp-29799).csv
# Saved new CSV file for Ba2BiSbO6(mp-1521651).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2BiSbO6(mp-1521651).csv
# Saved new CSV file for Sr2GdRuO6(mp-16796).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2GdRuO6(mp-16796).csv
# Saved new CSV file for Sr2YNbO6(mp-1520759).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2YNbO6(mp-1520759).csv
# Saved new CSV file for AlMoO3(mp-1373731).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlMoO3(mp-1373731).csv
# Saved new CSV file for La2MnCrO6(mp-1666963).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MnCrO6(mp-1666963).csv
# Saved new CSV file for DyErO3(mp-772188).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyErO3(mp-772188).csv
# Saved new CSV file for SmCuO3(mp-772548).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmCuO3(mp-772548).csv
# Saved new CSV file for Sc2MnNiO6(mp-1105225).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sc2MnNiO6(mp-1105225).csv
# Saved new CSV file for MnZnO3(mp-754318).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnZnO3(mp-754318).csv
# Saved new CSV file for SrMnO3(mp-1218206).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrMnO3(mp-1218206).csv
# Saved new CSV file for CaHfO3(mp-754853).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaHfO3(mp-754853).csv
# Saved new CSV file for Sr2CrReO6(mp-1205958).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CrReO6(mp-1205958).csv
# Saved new CSV file for GdBO3(mp-561949).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GdBO3(mp-561949).csv
# Saved new CSV file for LiNbO3(mp-552588).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiNbO3(mp-552588).csv
# Saved new CSV file for Ba2PrTiO6(mp-1520356).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrTiO6(mp-1520356).csv
# Saved new CSV file for ErAlO3(mp-754184).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ErAlO3(mp-754184).csv
# Saved new CSV file for La2ZnIrO6(mp-6152).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2ZnIrO6(mp-6152).csv
# Saved new CSV file for Sr2LuIrO6(mp-22726).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2LuIrO6(mp-22726).csv
# Saved new CSV file for Ca2TaVO6(mp-1373426).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TaVO6(mp-1373426).csv
# Saved new CSV file for Zn2CrIrO6(mp-1047076).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2CrIrO6(mp-1047076).csv
# Saved new CSV file for Sr2TaInO6(mp-1190108).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TaInO6(mp-1190108).csv
# Saved new CSV file for Zn2SnIrO6(mp-1368737).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2SnIrO6(mp-1368737).csv
# Saved new CSV file for LuCrO3(mp-755471).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LuCrO3(mp-755471).csv
# Saved new CSV file for Ca2FeReO6(mp-31763).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2FeReO6(mp-31763).csv
# Saved new CSV file for LuBO3(mp-7560).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LuBO3(mp-7560).csv
# Saved new CSV file for Na3V2PO9(mp-1221289).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Na3V2PO9(mp-1221289).csv
# Saved new CSV file for SrCrO3(mp-20029).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrCrO3(mp-20029).csv
# Saved new CSV file for La2GaCoO6(mp-1223269).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2GaCoO6(mp-1223269).csv
# Saved new CSV file for SmTmO3(mp-776439).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmTmO3(mp-776439).csv
# Saved new CSV file for Ba2DySbO6(mp-1522418).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2DySbO6(mp-1522418).csv
# Saved new CSV file for CsSbO3(mp-1185561).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsSbO3(mp-1185561).csv
# Saved new CSV file for AlBiO3(mp-551918).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlBiO3(mp-551918).csv
# Saved new CSV file for Nd2MgPtO6(mp-1209786).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Nd2MgPtO6(mp-1209786).csv
# Saved new CSV file for SrNbO3(mp-10339).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrNbO3(mp-10339).csv
# Saved new CSV file for Sr3Fe2RuO9(mp-1218474).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr3Fe2RuO9(mp-1218474).csv
# Saved new CSV file for SrZrO3(mp-1080575).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrZrO3(mp-1080575).csv
# Saved new CSV file for PrCrO3(mp-19353).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/PrCrO3(mp-19353).csv
# Saved new CSV file for MnAlO3(mp-774250).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnAlO3(mp-774250).csv
# Saved new CSV file for Ba2LaTaO6(mp-13055).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2LaTaO6(mp-13055).csv
# Saved new CSV file for SnPbO3(mp-504543).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SnPbO3(mp-504543).csv
# Saved new CSV file for Sr2NiMoO6(mp-25053).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NiMoO6(mp-25053).csv
# Saved new CSV file for CaCO3(mp-560265).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCO3(mp-560265).csv
# Saved new CSV file for CaCO3(mp-1197230).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCO3(mp-1197230).csv
# Saved new CSV file for CdGeO3(mp-1016903).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdGeO3(mp-1016903).csv
# Saved new CSV file for HoBO3(mp-754409).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoBO3(mp-754409).csv
# Saved new CSV file for Ba2VMoO6(mp-1079477).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2VMoO6(mp-1079477).csv
# Saved new CSV file for SbHO3(mp-626218).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SbHO3(mp-626218).csv
# Saved new CSV file for Ba2CePrO6(mp-1516858).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2CePrO6(mp-1516858).csv
# Saved new CSV file for OsPbO3(mp-680932).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/OsPbO3(mp-680932).csv
# Saved new CSV file for PbSeO3(mp-20716).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/PbSeO3(mp-20716).csv
# Saved new CSV file for SrSiO3(mp-561547).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrSiO3(mp-561547).csv
# Saved new CSV file for Ba2MnMoO6(mp-20399).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2MnMoO6(mp-20399).csv
# Saved new CSV file for Ca2YBiO6(mp-1518070).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2YBiO6(mp-1518070).csv
# Saved new CSV file for Zn2NiIrO6(mp-1047130).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2NiIrO6(mp-1047130).csv
# Saved new CSV file for Ba2PuMnO6(mp-1205598).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PuMnO6(mp-1205598).csv
# Saved new CSV file for BiSbO3(mp-755382).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BiSbO3(mp-755382).csv
# Saved new CSV file for Gd2NiRuO6(mp-1212785).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Gd2NiRuO6(mp-1212785).csv
# Saved new CSV file for Ba2NbCrO6(mp-31627).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NbCrO6(mp-31627).csv
# Saved new CSV file for CaCoO3(mp-1368304).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCoO3(mp-1368304).csv
# Saved new CSV file for LuRhO3(mp-1205366).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LuRhO3(mp-1205366).csv
# Saved new CSV file for DyBO3(mp-753318).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyBO3(mp-753318).csv
# Saved new CSV file for CdGeO3(mp-13003).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdGeO3(mp-13003).csv
# Saved new CSV file for BaSnO3(mp-1178513).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaSnO3(mp-1178513).csv
# Saved new CSV file for NbCuO3(mp-17272).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NbCuO3(mp-17272).csv
# Saved new CSV file for HoScO3(mp-31121).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoScO3(mp-31121).csv
# Saved new CSV file for Sr2CuMoO6(mp-1079351).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CuMoO6(mp-1079351).csv
# Saved new CSV file for Sr2NbGaO6(mp-1205677).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NbGaO6(mp-1205677).csv
# Saved new CSV file for KPO3(mp-5039).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KPO3(mp-5039).csv
# Saved new CSV file for Ba2NdVO6(mp-1520957).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NdVO6(mp-1520957).csv
# Saved new CSV file for TiCrO3(mp-755606).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiCrO3(mp-755606).csv
# Saved new CSV file for Ba2CuTeO6(mp-10335).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2CuTeO6(mp-10335).csv
# Saved new CSV file for Ba3Bi2RuO9(mp-1228299).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Bi2RuO9(mp-1228299).csv
# Saved new CSV file for La2MgCoO6(mp-1274653).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MgCoO6(mp-1274653).csv
# Saved new CSV file for EuInO3(mp-1212980).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuInO3(mp-1212980).csv
# Saved new CSV file for Ba3Cr2MoO9(mp-557755).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Cr2MoO9(mp-557755).csv
# Saved new CSV file for Eu2DyTaO6(mp-1205520).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2DyTaO6(mp-1205520).csv
# Saved new CSV file for SrRhO3(mp-1017441).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrRhO3(mp-1017441).csv
# Saved new CSV file for Ba2HoMoO6(mp-1205837).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2HoMoO6(mp-1205837).csv
# Saved new CSV file for Sr2MgWO6(mp-18848).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2MgWO6(mp-18848).csv
# Saved new CSV file for YTiO3(mp-1443298).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YTiO3(mp-1443298).csv
# Saved new CSV file for YTiO3(mp-1436662).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YTiO3(mp-1436662).csv
# Saved new CSV file for NaCrO3(mp-1076642).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaCrO3(mp-1076642).csv
# Saved new CSV file for Ba2UZnO6(mp-1078725).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2UZnO6(mp-1078725).csv
# Saved new CSV file for CeCrO3(mp-780712).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeCrO3(mp-780712).csv
# Saved new CSV file for Ba3ZrRu2O9(mp-561170).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3ZrRu2O9(mp-561170).csv
# Saved new CSV file for La2MnNiO6(mp-1223253).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MnNiO6(mp-1223253).csv
# Saved new CSV file for Ba2TbWO6(mp-1516516).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TbWO6(mp-1516516).csv
# Saved new CSV file for Sr2MnNbO6(mp-1288318).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2MnNbO6(mp-1288318).csv
# Saved new CSV file for ScCoO3(mp-754124).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ScCoO3(mp-754124).csv
# Saved new CSV file for GdCrO3(mp-18331).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GdCrO3(mp-18331).csv
# Saved new CSV file for MgSiO3(mp-3470).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-3470).csv
# Saved new CSV file for BaTbO3(mp-548824).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaTbO3(mp-548824).csv
# Saved new CSV file for Ba2GdWO6(mp-1519934).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2GdWO6(mp-1519934).csv
# Saved new CSV file for FeSnO3(mp-1207083).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/FeSnO3(mp-1207083).csv
# Saved new CSV file for CrMoO3(mp-1226313).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CrMoO3(mp-1226313).csv
# Saved new CSV file for ErBO3(mp-760405).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ErBO3(mp-760405).csv
# Saved new CSV file for La2CoNiO6(mp-1223259).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2CoNiO6(mp-1223259).csv
# Saved new CSV file for Li2MnWO6(mp-776740).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Li2MnWO6(mp-776740).csv
# Saved new CSV file for La2CrFeO6(mp-1223369).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2CrFeO6(mp-1223369).csv
# Saved new CSV file for CuAsO3(mp-1178368).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CuAsO3(mp-1178368).csv
# Saved new CSV file for TlCuO3(mp-1187483).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TlCuO3(mp-1187483).csv
# Saved new CSV file for DyScO3(mp-31120).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyScO3(mp-31120).csv
# Saved new CSV file for Ca2LaRuO6(mp-1227569).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2LaRuO6(mp-1227569).csv
# Saved new CSV file for Sr2TiMoO6(mp-1218376).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TiMoO6(mp-1218376).csv
# Saved new CSV file for BaSO3(mp-768307).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaSO3(mp-768307).csv
# Saved new CSV file for Mg2TaFeO6(mp-1345547).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2TaFeO6(mp-1345547).csv
# Saved new CSV file for RbOsO3(mp-998602).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/RbOsO3(mp-998602).csv
# Saved new CSV file for GdErO3(mp-1184486).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GdErO3(mp-1184486).csv
# Saved new CSV file for AlFeO3(mp-1254277).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlFeO3(mp-1254277).csv
# Saved new CSV file for Ti2MnZnO6(mp-1217104).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ti2MnZnO6(mp-1217104).csv
# Saved new CSV file for Sr3Fe2TeO9(mp-1218440).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr3Fe2TeO9(mp-1218440).csv
# Saved new CSV file for Ba2CaMoO6(mp-19403).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2CaMoO6(mp-19403).csv
# Saved new CSV file for InBiO3(mp-556892).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/InBiO3(mp-556892).csv
# Saved new CSV file for Ba2GdReO6(mp-1214941).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2GdReO6(mp-1214941).csv
# Saved new CSV file for TiSnO3(mp-754246).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiSnO3(mp-754246).csv
# Saved new CSV file for Ca2BiSbO6(mp-1331730).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2BiSbO6(mp-1331730).csv
# Saved new CSV file for MgSiO3(mp-4321).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-4321).csv
# Saved new CSV file for Ba2NdNbO6(mp-1518033).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NdNbO6(mp-1518033).csv
# Saved new CSV file for MgSO3(mp-769397).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSO3(mp-769397).csv
# Saved new CSV file for SrIrO3(mp-1193907).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrIrO3(mp-1193907).csv
# Saved new CSV file for CaCO3(mp-3953).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCO3(mp-3953).csv
# Saved new CSV file for MgSiO3(mp-642216).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-642216).csv
# Saved new CSV file for SrHfO3(mp-4551).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrHfO3(mp-4551).csv
# Saved new CSV file for TlBO3(mp-1187494).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TlBO3(mp-1187494).csv
# Saved new CSV file for Sr2PrSbO6(mp-1519896).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2PrSbO6(mp-1519896).csv
# Saved new CSV file for Ba2SmReO6(mp-13929).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmReO6(mp-13929).csv
# Saved new CSV file for Ba2SmSbO6(mp-1519474).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmSbO6(mp-1519474).csv
# Saved new CSV file for NdMnO3(mp-20852).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdMnO3(mp-20852).csv
# Saved new CSV file for SrGeO3(mp-555731).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrGeO3(mp-555731).csv
# Saved new CSV file for NaTaO3(mp-4699).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaTaO3(mp-4699).csv
# Saved new CSV file for Zn2CoIrO6(mp-1370320).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2CoIrO6(mp-1370320).csv
# Saved new CSV file for Ba2CaWO6(mp-18977).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2CaWO6(mp-18977).csv
# Saved new CSV file for EuCO3(mp-554518).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuCO3(mp-554518).csv
# Saved new CSV file for HfPbO3(mp-755790).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HfPbO3(mp-755790).csv
# Saved new CSV file for Sr2TaCrO6(mp-1539400).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TaCrO6(mp-1539400).csv
# Saved new CSV file for Sr2MnRuO6(mp-1218769).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2MnRuO6(mp-1218769).csv
# Saved new CSV file for RbNpO3(mp-975288).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/RbNpO3(mp-975288).csv
# Saved new CSV file for Ba3CaNb2O9(mp-1214569).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3CaNb2O9(mp-1214569).csv
# Saved new CSV file for Ba3Sm2WO9(mp-1228249).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Sm2WO9(mp-1228249).csv
# Saved new CSV file for Sr2ScOsO6(mp-1205575).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ScOsO6(mp-1205575).csv
# Saved new CSV file for MgSiO3(mp-5834).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-5834).csv
# Saved new CSV file for KBiO3(mp-982040).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KBiO3(mp-982040).csv
# Saved new CSV file for TmBO3(mp-17620).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TmBO3(mp-17620).csv
# Saved new CSV file for Sr2YRuO6(mp-14430).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2YRuO6(mp-14430).csv
# Saved new CSV file for Sr2HoTaO6(mp-1189408).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2HoTaO6(mp-1189408).csv
# Saved new CSV file for Sr2NbCoO6(mp-1274489).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NbCoO6(mp-1274489).csv
# Saved new CSV file for Sr2EuCrO6(mp-1517600).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2EuCrO6(mp-1517600).csv
# Saved new CSV file for CsNbO3(mp-27556).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsNbO3(mp-27556).csv
# Saved new CSV file for SrWO3(mp-1186764).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrWO3(mp-1186764).csv
# Saved new CSV file for BaTcO3(mp-555174).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaTcO3(mp-555174).csv
# Saved new CSV file for Y2CrFeO6(mp-1216153).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Y2CrFeO6(mp-1216153).csv
# Saved new CSV file for ErNiO3(mp-1189736).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ErNiO3(mp-1189736).csv
# Saved new CSV file for NaSbO3(mp-752755).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaSbO3(mp-752755).csv
# Saved new CSV file for Dy2NiRuO6(mp-1213197).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Dy2NiRuO6(mp-1213197).csv
# Saved new CSV file for Ba2NbRhO6(mp-1205833).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NbRhO6(mp-1205833).csv
# Saved new CSV file for SmMnO3(mp-22203).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SmMnO3(mp-22203).csv
# Saved new CSV file for YLuO3(mp-1101170).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YLuO3(mp-1101170).csv
# Saved new CSV file for La2MgIrO6(mp-6732).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MgIrO6(mp-6732).csv
# Saved new CSV file for YHoO3(mp-768889).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YHoO3(mp-768889).csv
# Saved new CSV file for LaMnO3(mp-1278230).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaMnO3(mp-1278230).csv
# Saved new CSV file for LaInO3(mp-11623).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaInO3(mp-11623).csv
# Saved new CSV file for KAsO3(mp-1184937).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KAsO3(mp-1184937).csv
# Saved new CSV file for PrNbO3(mp-975913).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/PrNbO3(mp-975913).csv
# Saved new CSV file for GaBiO3(mp-755568).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GaBiO3(mp-755568).csv
# Saved new CSV file for BaTbO3(mp-20129).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaTbO3(mp-20129).csv
# Saved new CSV file for TmVO3(mp-755258).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TmVO3(mp-755258).csv
# Saved new CSV file for Ba2TmMoO6(mp-1205595).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TmMoO6(mp-1205595).csv
# Saved new CSV file for CdSnO3(mp-1182642).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CdSnO3(mp-1182642).csv
# Saved new CSV file for MnAlO3(mp-1368992).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnAlO3(mp-1368992).csv
# Saved new CSV file for Ba2UCrO6(mp-1205611).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2UCrO6(mp-1205611).csv
# Saved new CSV file for LuNiO3(mp-19327).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LuNiO3(mp-19327).csv
# Saved new CSV file for TbBO3(mp-1217607).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbBO3(mp-1217607).csv
# Saved new CSV file for Mg2BiWO6(mp-1343439).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2BiWO6(mp-1343439).csv
# Saved new CSV file for CeCdO3(mp-1213812).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeCdO3(mp-1213812).csv
# Saved new CSV file for AlCoO3(mp-754022).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlCoO3(mp-754022).csv
# Saved new CSV file for LaCoO3(mp-1185232).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaCoO3(mp-1185232).csv
# Saved new CSV file for Ca2MnSbO6(mp-1566038).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2MnSbO6(mp-1566038).csv
# Saved new CSV file for CrBiO3(mp-23456).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CrBiO3(mp-23456).csv
# Saved new CSV file for ScFeO3(mp-754342).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ScFeO3(mp-754342).csv
# Saved new CSV file for NaOsO3(mp-998624).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaOsO3(mp-998624).csv
# Saved new CSV file for Ca2CeNiO6(mp-1520291).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2CeNiO6(mp-1520291).csv
# Saved new CSV file for Ba2LaReO6(mp-20958).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2LaReO6(mp-20958).csv
# Saved new CSV file for LiIO3(mp-23384).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiIO3(mp-23384).csv
# Saved new CSV file for Ca2FeWO6(mp-623098).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2FeWO6(mp-623098).csv
# Saved new CSV file for Ca2CuWO6(mp-1788667).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2CuWO6(mp-1788667).csv
# Saved new CSV file for Sr2LuRuO6(mp-20687).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2LuRuO6(mp-20687).csv
# Saved new CSV file for MgWO3(mp-1326513).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgWO3(mp-1326513).csv
# Saved new CSV file for Ca2SnWO6(mp-1875676).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2SnWO6(mp-1875676).csv
# Saved new CSV file for NdBO3(mp-13514).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdBO3(mp-13514).csv
# Saved new CSV file for Mg2BiWO6(mp-1047182).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2BiWO6(mp-1047182).csv
# Saved new CSV file for La3Mg2NbO9(mp-1223356).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La3Mg2NbO9(mp-1223356).csv
# Saved new CSV file for Mg2TiIrO6(mp-1342933).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2TiIrO6(mp-1342933).csv
# Saved new CSV file for NaPO3(mp-558192).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaPO3(mp-558192).csv
# Saved new CSV file for Ca2TaCrO6(mp-1214103).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TaCrO6(mp-1214103).csv
# Saved new CSV file for Sr2HfTiO6(mp-1218807).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2HfTiO6(mp-1218807).csv
# ...
# Saved new CSV file for Sr2NbCrO6(mp-1205690).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NbCrO6(mp-1205690).csv
# Saved new CSV file for Sr2ZrCrO6(mp-1080742).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2ZrCrO6(mp-1080742).csv
# Saved new CSV file for Sm2MnRhO6(mp-1219164).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sm2MnRhO6(mp-1219164).csv
# Saved new CSV file for MnInO3(mp-550807).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnInO3(mp-550807).csv
# Saved new CSV file for Ca2IrRhO6(mp-1227404).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2IrRhO6(mp-1227404).csv
# Saved new CSV file for LiNbO3(mp-1196213).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LiNbO3(mp-1196213).csv
# Saved new CSV file for DyGaO3(mp-769015).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyGaO3(mp-769015).csv
# Saved new CSV file for Ca3ZrSi2O9(mp-15004).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca3ZrSi2O9(mp-15004).csv
# Saved new CSV file for Ca2MnReO6(mp-1106155).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2MnReO6(mp-1106155).csv
# Saved new CSV file for Eu2HfSnO6(mp-1517993).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2HfSnO6(mp-1517993).csv
# Saved new CSV file for LaPdO3(mp-16415).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaPdO3(mp-16415).csv
# Saved new CSV file for VHO3(mp-627209).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VHO3(mp-627209).csv
# Saved new CSV file for Eu2ZrTiO6(mp-1520462).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2ZrTiO6(mp-1520462).csv
# Saved new CSV file for AlGaO3(mp-772898).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlGaO3(mp-772898).csv
# Saved new CSV file for Ca2NiWO6(mp-1397424).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2NiWO6(mp-1397424).csv
# Saved new CSV file for SrZrO3(mp-3626).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrZrO3(mp-3626).csv
# Saved new CSV file for CaRhO3(mp-1016833).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaRhO3(mp-1016833).csv
# Saved new CSV file for CeAsO3(mp-1195015).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeAsO3(mp-1195015).csv
# Saved new CSV file for MgSiO3(mp-1020123).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-1020123).csv
# Saved new CSV file for Ba2TiMnO6(mp-1228358).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TiMnO6(mp-1228358).csv
# Saved new CSV file for TbVO3(mp-554811).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbVO3(mp-554811).csv
# Saved new CSV file for CeCuO3(mp-977389).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CeCuO3(mp-977389).csv
# Saved new CSV file for SrPtO3(mp-1187202).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrPtO3(mp-1187202).csv
# Saved new CSV file for AlRhO3(mp-1178547).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlRhO3(mp-1178547).csv
# Saved new CSV file for Ba2PrSbO6(mp-1521617).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrSbO6(mp-1521617).csv
# Saved new CSV file for YBiO3(mp-1406000).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/YBiO3(mp-1406000).csv
# Saved new CSV file for KSbO3(mp-547792).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KSbO3(mp-547792).csv
# Saved new CSV file for NdCrO3(mp-19269).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdCrO3(mp-19269).csv
# Saved new CSV file for MgCO3(mp-5348).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgCO3(mp-5348).csv
# Saved new CSV file for AlSbO3(mp-1384267).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlSbO3(mp-1384267).csv
# Saved new CSV file for MgSiO3(mp-1199778).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgSiO3(mp-1199778).csv
# Saved new CSV file for TbErO3(mp-756048).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbErO3(mp-756048).csv
# Saved new CSV file for LuMnO3(mp-18808).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LuMnO3(mp-18808).csv
# Saved new CSV file for Mg2CoSbO6(mp-1344636).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2CoSbO6(mp-1344636).csv
# Saved new CSV file for Ba2AgIO6(mp-1206237).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2AgIO6(mp-1206237).csv
# Saved new CSV file for Ba2TaMnO6(mp-1307944).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TaMnO6(mp-1307944).csv
# Saved new CSV file for Ba2SrCrO6(mp-1522756).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SrCrO6(mp-1522756).csv
# Saved new CSV file for NaAsO3(mp-17868).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaAsO3(mp-17868).csv
# Saved new CSV file for Nd2ZnPtO6(mp-1209914).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Nd2ZnPtO6(mp-1209914).csv
# Saved new CSV file for La2MnCrO6(mp-1223342).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MnCrO6(mp-1223342).csv
# Saved new CSV file for NdBiO3(mp-974740).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdBiO3(mp-974740).csv
# Saved new CSV file for Sr2GdBiO6(mp-1208851).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2GdBiO6(mp-1208851).csv
# Saved new CSV file for MnCoO3(mp-1181286).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MnCoO3(mp-1181286).csv
# Saved new CSV file for Ca2TaFeO6(mp-1341944).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2TaFeO6(mp-1341944).csv
# Saved new CSV file for Ba2PuInO6(mp-1205697).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PuInO6(mp-1205697).csv
# Saved new CSV file for PrFeO3(mp-22341).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/PrFeO3(mp-22341).csv
# Saved new CSV file for NaVO3(mp-763901).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaVO3(mp-763901).csv
# Saved new CSV file for CaTeO3(mp-561374).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaTeO3(mp-561374).csv
# Saved new CSV file for Ba2TbBiO6(mp-552191).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TbBiO6(mp-552191).csv
# Saved new CSV file for Ba2PrRuO6(mp-6183).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrRuO6(mp-6183).csv
# Saved new CSV file for Sr2EuBiO6(mp-1518150).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2EuBiO6(mp-1518150).csv
# Saved new CSV file for EuNpO3(mp-1213363).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuNpO3(mp-1213363).csv
# Saved new CSV file for CoBiO3(mp-545522).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CoBiO3(mp-545522).csv
# Saved new CSV file for NaVO3(mp-1101657).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NaVO3(mp-1101657).csv
# Saved new CSV file for CoCO3(mp-21434).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CoCO3(mp-21434).csv
# Saved new CSV file for BiBO3(mp-31250).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BiBO3(mp-31250).csv
# Saved new CSV file for CaSeO3(mp-557997).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaSeO3(mp-557997).csv
# Saved new CSV file for La2MgMnO6(mp-19406).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MgMnO6(mp-19406).csv
# Saved new CSV file for La2CrMoO6(mp-1223257).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2CrMoO6(mp-1223257).csv
# Saved new CSV file for Ba2NdReO6(mp-1205556).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NdReO6(mp-1205556).csv
# Saved new CSV file for Ba2YOsO6(mp-1078303).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2YOsO6(mp-1078303).csv
# Saved new CSV file for BaCoO3(mp-1076782).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaCoO3(mp-1076782).csv
# Saved new CSV file for BaMnO3(mp-557535).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaMnO3(mp-557535).csv
# Saved new CSV file for NdTiO3(mp-3119).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdTiO3(mp-3119).csv
# Saved new CSV file for TmScO3(mp-1207696).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TmScO3(mp-1207696).csv
# Saved new CSV file for VAgO3(mp-1100926).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/VAgO3(mp-1100926).csv
# Saved new CSV file for Ba2SmNbO6(mp-22184).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmNbO6(mp-22184).csv
# Saved new CSV file for HoBO3(mp-1184546).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/HoBO3(mp-1184546).csv
# Saved new CSV file for CuSeO3(mp-22688).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CuSeO3(mp-22688).csv
# Saved new CSV file for FeBiO3(mp-548231).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/FeBiO3(mp-548231).csv
# Saved new CSV file for Ba2SmCrO6(mp-1523013).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2SmCrO6(mp-1523013).csv
# Saved new CSV file for LaTaO3(mp-1239192).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaTaO3(mp-1239192).csv
# Saved new CSV file for TaTlO3(mp-861873).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TaTlO3(mp-861873).csv
# Saved new CSV file for KBrO3(mp-22958).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KBrO3(mp-22958).csv
# Saved new CSV file for SrCrO3(mp-1372100).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/SrCrO3(mp-1372100).csv
# Saved new CSV file for Pr2CoRuO6(mp-1209770).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Pr2CoRuO6(mp-1209770).csv
# Saved new CSV file for ErBiO3(mp-754943).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/ErBiO3(mp-754943).csv
# Saved new CSV file for Zn2FeIrO6(mp-1301773).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Zn2FeIrO6(mp-1301773).csv
# Saved new CSV file for Na3SbP2O9(mp-560642).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Na3SbP2O9(mp-560642).csv
# Saved new CSV file for Ca2VBiO6(mp-1518804).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2VBiO6(mp-1518804).csv
# Saved new CSV file for Mg2CrSbO6(mp-1275594).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Mg2CrSbO6(mp-1275594).csv
# Saved new CSV file for Eu2YVO6(mp-1522779).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Eu2YVO6(mp-1522779).csv
# Saved new CSV file for Sr2TiMnO6(mp-1206645).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TiMnO6(mp-1206645).csv
# Saved new CSV file for CsMoO3(mp-1183917).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsMoO3(mp-1183917).csv
# Saved new CSV file for Ti2VHO6(mp-1195787).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ti2VHO6(mp-1195787).csv
# Saved new CSV file for La2FeNiO6(mp-1223335).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2FeNiO6(mp-1223335).csv
# Saved new CSV file for Ba2PrSeO6(mp-1521257).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrSeO6(mp-1521257).csv
# Saved new CSV file for Ca2HfZrO6(mp-1522139).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ca2HfZrO6(mp-1522139).csv
# Saved new CSV file for Ba2MnTeO6(mp-18992).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2MnTeO6(mp-18992).csv
# Saved new CSV file for Sm2MnNiO6(mp-555010).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sm2MnNiO6(mp-555010).csv
# Saved new CSV file for Ba2NdReO6(mp-1214644).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2NdReO6(mp-1214644).csv
# Saved new CSV file for LaVO3(mp-19350).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/LaVO3(mp-19350).csv
# Saved new CSV file for BaCO3(mp-5504).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaCO3(mp-5504).csv
# Saved new CSV file for La2MgTiO6(mp-1412249).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MgTiO6(mp-1412249).csv
# Saved new CSV file for Ba3Ta2CdO9(mp-554669).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Ta2CdO9(mp-554669).csv
# Saved new CSV file for KIO3(mp-1200675).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KIO3(mp-1200675).csv
# Saved new CSV file for BaHfO3(mp-998552).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaHfO3(mp-998552).csv
# Saved new CSV file for CaCO3(mp-4626).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCO3(mp-4626).csv
# Saved new CSV file for Li3MnP2O9(mp-867845).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Li3MnP2O9(mp-867845).csv
# Saved new CSV file for KVO3(mp-1076633).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/KVO3(mp-1076633).csv
# Saved new CSV file for AlCoO3(mp-1386773).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/AlCoO3(mp-1386773).csv
# Saved new CSV file for DyCoO3(mp-22137).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyCoO3(mp-22137).csv
# Saved new CSV file for GdAlO3(mp-1178268).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/GdAlO3(mp-1178268).csv
# Saved new CSV file for Sr2TbCrO6(mp-1520970).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2TbCrO6(mp-1520970).csv
# Saved new CSV file for Ba3Nb2CoO9(mp-31514).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba3Nb2CoO9(mp-31514).csv
# Saved new CSV file for Sr2NiIrO6(mp-1078518).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NiIrO6(mp-1078518).csv
# Saved new CSV file for Ba2TmReO6(mp-13934).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2TmReO6(mp-13934).csv
# Saved new CSV file for TmScO3(mp-1187557).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TmScO3(mp-1187557).csv
# Saved new CSV file for CaCoO3(mp-1399298).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CaCoO3(mp-1399298).csv
# Saved new CSV file for DyCrO3(mp-19381).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/DyCrO3(mp-19381).csv
# Saved new CSV file for NdTaO3(mp-1186324).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/NdTaO3(mp-1186324).csv
# Saved new CSV file for CsRuO3(mp-1183971).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsRuO3(mp-1183971).csv
# Saved new CSV file for Dy2TiCuO6(mp-1225458).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Dy2TiCuO6(mp-1225458).csv
# Saved new CSV file for BaNpO3(mp-8558).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/BaNpO3(mp-8558).csv
# Saved new CSV file for TiNiO3(mp-531689).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TiNiO3(mp-531689).csv
# Saved new CSV file for CuSiO3(mp-556982).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CuSiO3(mp-556982).csv
# Saved new CSV file for CuPO3(mp-772192).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CuPO3(mp-772192).csv
# Saved new CSV file for Sr2NdSbO6(mp-1516795).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2NdSbO6(mp-1516795).csv
# Saved new CSV file for MgCoO3(mp-756102).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/MgCoO3(mp-756102).csv
# Saved new CSV file for EuFeO3(mp-504703).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/EuFeO3(mp-504703).csv
# Saved new CSV file for Sr2LaBiO6(mp-1518083).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2LaBiO6(mp-1518083).csv
# Saved new CSV file for Sr2CaWO6(mp-18742).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Sr2CaWO6(mp-18742).csv
# Saved new CSV file for Ba2PrVO6(mp-1519938).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2PrVO6(mp-1519938).csv
# Saved new CSV file for Ba2YRuO6(mp-6428).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Ba2YRuO6(mp-6428).csv
# Saved new CSV file for Gd2MnCoO6(mp-1224833).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/Gd2MnCoO6(mp-1224833).csv
# Saved new CSV file for La2MgMoO6(mp-1233315).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/La2MgMoO6(mp-1233315).csv
# Saved new CSV file for TbTmO3(mp-756762).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/TbTmO3(mp-756762).csv
# Saved new CSV file for CsPO3(mp-1213232).csv to /Users/yangmingyue/Desktop/ABO365/模型应用新新/配位数化合价离子半径/CsPO3(mp-1213232).csv
# Processing complete.

# %%
import pandas as pd
import os
import math

# --- Configuration starts ---
input_folder = '/ionic radium/'  # Path to the input folder containing CSV files
output_folder = '/ionic Vm/' # Path to the output folder for processed files
radius_column_name = 'IR'                # Column name for ionic radius in the input CSV
ion_column_name = 'ion'                  # Column name for the ion identifier in the input CSV
# --- Configuration ends ---

def calculate_and_average_ionic_volumes(input_filepath, output_filepath):
    """
    Reads a CSV file, calculates ionic volumes from radii,
    averages them per ion type, and saves the result.
    """
    try:
        df = pd.read_csv(input_filepath)
        print(f"Processing file: {input_filepath}")

        # Check if necessary columns exist
        if radius_column_name not in df.columns:
            print(f"Error: Radius column '{radius_column_name}' not found in file {input_filepath}. Skipping this file.")
            return
        if ion_column_name not in df.columns:
            print(f"Error: Ion identifier column '{ion_column_name}' not found in file {input_filepath}. Skipping this file.")
            return

        # Convert radius column to numeric, coercing errors to NaN
        df[radius_column_name] = pd.to_numeric(df[radius_column_name], errors='coerce')
        
        # Handle rows with non-numeric or missing radii
        original_rows = len(df)
        df.dropna(subset=[radius_column_name], inplace=True)
        if len(df) < original_rows:
            print(f"Warning: Removed {original_rows - len(df)} rows from file {input_filepath} because the '{radius_column_name}' column contained non-numeric or null values.")

        if df.empty:
            print(f"Warning: File {input_filepath} is empty after removing invalid radii. Skipping this file.")
            return

        # Calculate ionic volume: V = (4/3) * pi * r^3
        df['ionic_volume'] = (4/3) * math.pi * (df[radius_column_name] ** 3)

        # Group by ion type and calculate the mean ionic volume
        average_volumes_df = df.groupby(ion_column_name, as_index=False)['ionic_volume'].mean()

        # Rename the resulting column for clarity
        average_volumes_df.rename(columns={'ionic_volume': 'average_ionic_volume'}, inplace=True)

        # Save the result to a new CSV file
        average_volumes_df.to_csv(output_filepath, index=False, encoding='utf-8-sig') # utf-8-sig ensures correct display in Excel, especially with non-ASCII characters if any were present in ion names
        print(f"Processed and saved results to: {output_filepath}")

    except FileNotFoundError:
        print(f"Error: Input file {input_filepath} not found.")
    except pd.errors.EmptyDataError:
        print(f"Error: Input file {input_filepath} is empty.")
    except Exception as e:
        print(f"An unexpected error occurred while processing file {input_filepath}: {e}")

def main():
    """
    Main function to orchestrate the processing of CSV files.
    """
    # Check if input folder exists
    if not os.path.isdir(input_folder):
        print(f"Error: Input folder '{input_folder}' does not exist. Please check the path.")
        return

    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Created output folder: {output_folder}")

    # Get a list of CSV files in the input folder
    csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

    if not csv_files:
        print(f"No CSV files found in folder '{input_folder}'.")
        return

    print(f"Found {len(csv_files)} CSV files to process.")

    # Process each CSV file
    for filename in csv_files:
        input_filepath = os.path.join(input_folder, filename)

        # Construct output filename
        base, ext = os.path.splitext(filename)
        output_filename = f"{base}_avg_volume{ext}" # Appending suffix to distinguish output
        output_filepath = os.path.join(output_folder, output_filename)

        calculate_and_average_ionic_volumes(input_filepath, output_filepath)

    print("\nAll files processed.")

if __name__ == "__main__":
    main()
# Out:
# 找到 3097 个CSV文件待处理。
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba3ZrIr2O9(mp-1214509).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba3ZrIr2O9(mp-1214509)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2SmWO6(mp-1517191).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2SmWO6(mp-1517191)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/InRhO3(mp-1203220).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/InRhO3(mp-1203220)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Mg2SbWO6(mp-1047279).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Mg2SbWO6(mp-1047279)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/TbVO3(mp-1187389).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/TbVO3(mp-1187389)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2ScTaO6(mp-1205823).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2ScTaO6(mp-1205823)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Sr2UInO6(mp-1206007).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Sr2UInO6(mp-1206007)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/MnZnO3(mp-772528).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/MnZnO3(mp-772528)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/BaIrO3(mp-5660).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/BaIrO3(mp-5660)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2GdNbO6(mp-19996).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2GdNbO6(mp-19996)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2GdUO6(mp-1205845).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2GdUO6(mp-1205845)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/EuAgO3(mp-1077622).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/EuAgO3(mp-1077622)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/La2ZnCoO6(mp-1272890).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/La2ZnCoO6(mp-1272890)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba3Ta2MnO9(mp-1214505).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba3Ta2MnO9(mp-1214505)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/SrRuO3(mp-4525).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/SrRuO3(mp-4525)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/SmCrO3(mp-19257).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/SmCrO3(mp-19257)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Tb2CoPtO6(mp-1208543).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Tb2CoPtO6(mp-1208543)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/BaPrO3(mp-4783).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/BaPrO3(mp-4783)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/LiVO3(mp-754098).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/LiVO3(mp-754098)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/K3NaRe2O9(mp-541393).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/K3NaRe2O9(mp-541393)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/CuAsO3(mp-776320).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/CuAsO3(mp-776320)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/CeSbO3(mp-38685).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/CeSbO3(mp-38685)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ca2MnNiO6(mp-1326305).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ca2MnNiO6(mp-1326305)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径
_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Sr2CaWO6(mp-18742).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Sr2CaWO6(mp-18742)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2PrVO6(mp-1519938).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2PrVO6(mp-1519938)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Ba2YRuO6(mp-6428).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Ba2YRuO6(mp-6428)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/Gd2MnCoO6(mp-1224833).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/Gd2MnCoO6(mp-1224833)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/La2MgMoO6(mp-1233315).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/La2MgMoO6(mp-1233315)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/TbTmO3(mp-756762).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/TbTmO3(mp-756762)_avg_volume.csv
# 正在处理文件: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子半径/CsPO3(mp-1213232).csv
# 已处理并保存结果到: /Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/CsPO3(mp-1213232)_avg_volume.csv
#
# 所有文件处理完毕。

# %%
import os
import pandas as pd
import re


input_folder = "/Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/"
output_file = "/Users/yangmingyue/Desktop/ABO365/模型应用新新/总离子体积.csv"


results = []


for filename in os.listdir(input_folder):
    if filename.endswith('_avg_volume.csv'):

        match = re.match(r'([^(]+)\(([^)]+)\)', os.path.splitext(filename)[0])
        if match:
            formula = match.group(1)
            mp = match.group(2)
            formula_mp = f"{formula}({mp})"
        else:
            continue


        file_path = os.path.join(input_folder, filename)


        df = pd.read_csv(file_path)


        ions = re.findall(r'([A-Z][a-z]*)(\d*)', formula)
        ion_dict = {ion: int(coeff) if coeff else 1 for ion, coeff in ions}


        total_volume = 0
        for _, row in df.iterrows():
            ion = row['ion']
            volume = row['average_ionic_volume']
            if ion in ion_dict:
                total_volume += volume * ion_dict[ion]


        results.append({'formula_mp': formula_mp, 'total_ionic_volume': total_volume})


result_df = pd.DataFrame(results)
result_df.to_csv(output_file, index=False)
print(f"over {output_file}")
# Out:
# 处理完成，结果已保存到 /Users/yangmingyue/Desktop/ABO365/模型应用新新/总离子体积.csv

# %%
import os
import pandas as pd
import re


input_folder = "/Users/yangmingyue/Desktop/ABO365/模型应用新新/修改后配位数化合价离子体积/"
output_file = "/Users/yangmingyue/Desktop/ABO365/模型应用新新/总离子体积处理后.csv"


results = []


for filename in os.listdir(input_folder):
    if filename.endswith('_avg_volume.csv'):

        match = re.match(r'([^(]+)\(([^)]+)\)', os.path.splitext(filename)[0])
        if match:
            formula = match.group(1)
            mp = match.group(2)
            formula_mp = f"{formula}({mp})"
        else:
            continue


        file_path = os.path.join(input_folder, filename)


        df = pd.read_csv(file_path)


        ions = re.findall(r'([A-Z][a-z]*)(\d*)', formula)
        ion_dict = {ion: int(coeff) if coeff else 1 for ion, coeff in ions}


        o_match = re.search(r'O(\d+)(\))?', formula)
        if o_match:
            o_coeff = int(o_match.group(1))
            if o_match.group(2): 
                print(f"Skipping {formula_mp} due to 'O{coeff})'")
                continue
            divisor = o_coeff // 3  
        else:
            divisor = 1  


        total_volume = 0
        for _, row in df.iterrows():
            ion = row['ion']
            volume = row['average_ionic_volume']
            if ion in ion_dict:
                total_volume += volume * ion_dict[ion]


        adjusted_volume = total_volume / divisor


        results.append({'formula_mp': formula_mp, 'total_ionic_volume': adjusted_volume})


result_df = pd.DataFrame(results)
result_df.to_csv(output_file, index=False)
print(f"over {output_file}")
# Out:
# 处理完成，结果已保存到 /Users/yangmingyue/Desktop/ABO365/模型应用新新/总离子体积处理后.csv
